# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
series=pd.Series(data)
print("serries \n",series)
print(type(series))
# Out:
# serries
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# Create series from dict
data={'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)
print(type(series_dict))
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#Data frame 
# create a Data frame a dictionery of list 
data ={
    'Name': ['krish','john','jack'],
    'age':[25,30,45],
    'city':['Banglore','NewYork','Florida']
}

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  age      city
# 0  krish   25  Banglore
# 1   john   30   NewYork
# 2   jack   45   Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
np.array(df)
# Out:
# array([['krish', 25, 'Banglore'],
#        ['john', 30, 'NewYork'],
#        ['jack', 45, 'Florida']], dtype=object)

# %%
# creat a data frame from list of dict
data =[
    {'Name':'krish','Age':42,'City':'banglore'},
     {'Name':'prathamesh','Age':34,'City':'chakan'},
      {'Name':'pravin','Age':13,'City':'pune'}
    
]
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#          Name  Age      City
# 0       krish   42  banglore
# 1  prathamesh   34    chakan
# 2      pravin   13      pune
# <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.read_csv('test.csv')
df.head(5)
# Out:
#         Date Total Sales ($)  Number of Orders  Average Order Value ($)  \
# 0  01-Jul-25           3,150                38                    82.89
# 1  02-Jul-25           4,200                45                    93.33
# 2  03-Jul-25           3,800                41                    92.68
# 3  04-Jul-25           5,500                60                    91.67
#
#    Conversion Rate (%)  New Customers  Returning Customers  \
# 0                  3.2             11                   27
# 1                  4.1             18                   27
# 2                  3.7             15                   26
# 3                  5.3             25                   35
#
#    Customer Acquisition Cost ($)  Customer Lifetime Value ($)  \
# 0                             55                          280
# 1                             42                          310
# 2                             48                          295
# ...

# %%
df.tail(5)
# Out:
#         Date Total Sales ($)  Number of Orders  Average Order Value ($)  \
# 0  01-Jul-25           3,150                38                    82.89
# 1  02-Jul-25           4,200                45                    93.33
# 2  03-Jul-25           3,800                41                    92.68
# 3  04-Jul-25           5,500                60                    91.67
#
#    Conversion Rate (%)  New Customers  Returning Customers  \
# 0                  3.2             11                   27
# 1                  4.1             18                   27
# 2                  3.7             15                   26
# 3                  5.3             25                   35
#
#    Customer Acquisition Cost ($)  Customer Lifetime Value ($)  \
# 0                             55                          280
# 1                             42                          310
# 2                             48                          295
# ...

# %%
#accesing data from data frame 
df['Date']
# Out:
# 0    01-Jul-25
# 1    02-Jul-25
# 2    03-Jul-25
# 3    04-Jul-25
# Name: Date, dtype: object

# %%
df.loc[0][6]
# Out:
# C:\Users\prathamesh kolhe\AppData\Local\Temp\ipykernel_19920\3333638368.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][6]
# '27'

# %%
df.iloc[0][6]
# Out:
# C:\Users\prathamesh kolhe\AppData\Local\Temp\ipykernel_19920\1424552850.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][6]
# '27'

# %%
## accesing a specified elemnt
df.at[23,'Date']
# Out:
# '24-Jul-25'

# %%
# Accesing spoecified element using iat 
df.iat[2,2]
# Out:
# '41'

# %%
# Data manupilation with df

# %%
# Adding a Column
df['Salary']=[2345,2455,6264,646]
df
# Out:
#         Date Total Sales ($)  Number of Orders  Average Order Value ($)  \
# 0  01-Jul-25           3,150                38                    82.89
# 1  02-Jul-25           4,200                45                    93.33
# 2  03-Jul-25           3,800                41                    92.68
# 3  04-Jul-25           5,500                60                    91.67
#
#    Conversion Rate (%)  New Customers  Returning Customers  \
# 0                  3.2             11                   27
# 1                  4.1             18                   27
# 2                  3.7             15                   26
# 3                  5.3             25                   35
#
#    Customer Acquisition Cost ($)  Customer Lifetime Value ($)  \
# 0                             55                          280
# 1                             42                          310
# 2                             48                          295
# ...

# %%
# Remoe a column 
df.drop('Salary',axis=1,inplace=True)
# inplace=true means it permently modified

# %%
df
# Out:
#         Date Total Sales ($)  Number of Orders  Average Order Value ($)  \
# 0  01-Jul-25           3,150                38                    82.89
# 1  02-Jul-25           4,200                45                    93.33
# 2  03-Jul-25           3,800                41                    92.68
# 3  04-Jul-25           5,500                60                    91.67
#
#    Conversion Rate (%)  New Customers  Returning Customers  \
# 0                  3.2             11                   27
# 1                  4.1             18                   27
# 2                  3.7             15                   26
# 3                  5.3             25                   35
#
#    Customer Acquisition Cost ($)  Customer Lifetime Value ($)  \
# 0                             55                          280
# 1                             42                          310
# 2                             48                          295
# ...

# %%
# modified total sales
df['Salary']=df['Salary']+1000
df
# Out:
#         Date Total Sales ($)  Number of Orders  Average Order Value ($)  \
# 0  01-Jul-25           3,150                38                    82.89
# 1  02-Jul-25           4,200                45                    93.33
# 2  03-Jul-25           3,800                41                    92.68
# 3  04-Jul-25           5,500                60                    91.67
#
#    Conversion Rate (%)  New Customers  Returning Customers  \
# 0                  3.2             11                   27
# 1                  4.1             18                   27
# 2                  3.7             15                   26
# 3                  5.3             25                   35
#
#    Customer Acquisition Cost ($)  Customer Lifetime Value ($)  \
# 0                             55                          280
# 1                             42                          310
# 2                             48                          295
# ...

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#         Date Total Sales ($)  Number of Orders  Average Order Value ($)  \
# 1  02-Jul-25           4,200                45                    93.33
# 2  03-Jul-25           3,800                41                    92.68
# 3  04-Jul-25           5,500                60                    91.67
#
#    Conversion Rate (%)  New Customers  Returning Customers  \
# 1                  4.1             18                   27
# 2                  3.7             15                   26
# 3                  5.3             25                   35
#
#    Customer Acquisition Cost ($)  Customer Lifetime Value ($)  \
# 1                             42                          310
# 2                             48                          295
# 3                             35                          350
#
#   Product A Sales ($) Product B Sales ($)  Product C Sales ($)  \
# 1               2,100               1,500                  600
# ...
